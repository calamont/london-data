# %% [markdown]
# # Word embeddings
# Using word embeddings to (hopefully) improve prediction accuracy of our property listing classification data set.

# %%
import json
import numpy as np
import pandas as pd
from cleaning import process_text
from sklearn.model_selection import train_test_split

df = pd.read_json('property_descriptions.json')
df['description'] = df['description'].apply(process_text)
x_train, x_test, y_train, y_test = train_test_split(
    df['description'], df['advertiser'], test_size=0.3)
sentences = []
for descriptions in x_train:
    sentences.append(descriptions)

# %% [markdown]
# ## word2Vec

# %%
# Initialize and train the model.
from gensim.models import word2vec
model = word2vec.Word2Vec(sentences, workers=4, size=300, 
                          min_count = 40, window = 10, sample = 1e-3)
model.init_sims(replace=True)

# %% [markdown]
# ### Averaging vectors
# An option for utilising word2Vec is by averaging the word vectors within each sample of text. Pretty basic but worth checking out how well this works.

# %%
def average_text(text):
    """Use trained word2vec model to average property descriptions"""
    text = text.values
    text_matrix = np.zeros((text.shape[0], 300))
    for i in range(text.shape[0]):
        text_sum = 0
        count = 0
        words = text[i]
        for word in words:
            try:
                text_sum += model.wv.get_vector(word)
                count += 1
            except KeyError:
                pass
        if count != 0:
            text_matrix[i,:] = text_sum / count
        else:
            text_matrix[i,:] = np.zeros(300)
    return text_matrix
            
x_train = average_text(x_train)
x_test = average_text(x_test)

# Train SVC with average vectors.
from sklearn.metrics import classification_report
from sklearn import svm
clf = svm.LinearSVC()
clf.fit(x_train, y_train)
pred = clf.predict(x_test)
print(classification_report(y_test, pred))
# Out:
#              precision    recall  f1-score   support
#
#       agent       0.75      0.83      0.79      2625
#    flatmate       0.70      0.73      0.71      2673
#    landlord       0.66      0.58      0.61      3043
#
# avg / total       0.70      0.70      0.70      8341

# %% [markdown]
# ## doc2vec

# %%
import json
from gensim.models import doc2vec
from collections import namedtuple
import pandas as pd
from cleaning import process_text_doc2vec
from gensim.models.doc2vec import TaggedDocument
SentimentDocument = namedtuple('SentimentDocument', 'words tags')

df = pd.read_json('property_descriptions.json')
df['description'] = df['description'].apply(process_text_doc2vec)
# x_train, x_test, y_train, y_test = train_test_split(df['description'], df['advertiser'], test_size=0.3)
sentences = []
raw_sentences = []
count = 0
for listing in df.index:
    tag = 'LISTING_' + str(count)
#     sentences.append(SentimentDocument(df.loc[listing,'description'], [tag, df.loc[listing,'advertiser']]))
#     sentences.append(TaggedDocument(df.loc[listing,'description'], [tag]))
#     sentences.append(TaggedDocument(df.loc[listing,'description'], [tag, df.loc[listing,'advertiser']]))
    sentences.append(TaggedDocument(df.loc[listing,'description'], [df.loc[listing,'advertiser']]))
    raw_sentences += df.loc[listing,'description']
    count += 1 
# Train a number of samples to compare performance.    
models = [
#     doc2vec.Doc2Vec(dm=1, dm_concat=1, size=100, window=5, negative=5, hs=0, min_count=2, workers=4),
    doc2vec.Doc2Vec(dm=0, size=100, negative=5, hs=0, min_count=2, workers=4),
#     doc2vec.Doc2Vec(dm=0, size=300, negative=5, hs=0, min_count=2, workers=4),
    doc2vec.Doc2Vec(dm=1, dm_mean=1, size=100, window=10, negative=5, hs=0, min_count=2, workers=4),
#     doc2vec.Doc2Vec(dm=1, dm_concat=1, size=100, window=5, negative=5, hs=0, min_count=2, workers=4)
#     doc2vec.Doc2Vec(dm=1, dm_mean=1, size=100, window=10, negative=5, hs=0, min_count=0, workers=4)
#     doc2vec.Doc2Vec(dm=1, dm_mean=1, size=400, window=10, hs=1, min_count=2, workers=4)
]
# model = doc2vec.Doc2Vec(size=100, window=4, min_count=5, workers=4)
models[0].build_vocab(sentences)
for model in models[1:]:
    model.reset_from(models[0])
# Out:
# /Users/cal_lamont/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:359: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")

# %%
t = models[0]

# %%
sentences[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-2a39db64c3cc> in <module>()
# ----> 1 sentences[0]['LISTING_6302']
#
# TypeError: tuple indices must be integers or slices, not str

# %%
# Load existing model or train new model
# model = Doc2Vec.load('./imdb.d2v')
import numpy as np
import time 
from sklearn.metrics.pairwise import cosine_similarity

passes = 20
alpha = 0.025
min_alpha = 0.001
alpha_delta = (alpha - min_alpha) / passes
vector = np.zeros((passes, 100))
from numpy.random import shuffle
# Manually run through each epoch to shuffle data for building.
for epoch in range(passes):
    start = time.time()
    shuffle(sentences)
    for train_model in models:
        train_model.alpha, train_model.min_alpha = alpha, alpha
        train_model.train(sentences, total_examples=len(sentences), epochs=1)
        train_model['agent']
        vector[epoch, :] = np.reshape(train_model['agent'],-1)
#         print(cosine_similarity(vector[epoch,:], vector[0,:]))
    alpha -= alpha_delta
    end = time.time()
    elapsed = end-start
    print(f"Time elapsed for epoch {epoch}: {elapsed}")
    
# model.save('./listing_model.d2v')
# model.delete_temporary_training_data(keep_doctags_vectors=True, keep_inference=True)
# Out:
# Time elapsed for epoch 0: 6.640905380249023
# Time elapsed for epoch 1: 6.726337909698486
# Time elapsed for epoch 2: 7.002516031265259
# Time elapsed for epoch 3: 6.670045852661133
# Time elapsed for epoch 4: 6.68124794960022
# Time elapsed for epoch 5: 6.719854116439819
# Time elapsed for epoch 6: 6.689558029174805
# Time elapsed for epoch 7: 6.659426212310791
# Time elapsed for epoch 8: 6.707438230514526
# Time elapsed for epoch 9: 7.138041734695435
# Time elapsed for epoch 10: 6.670548915863037
# Time elapsed for epoch 11: 6.873135089874268
# Time elapsed for epoch 12: 6.646896839141846
# Time elapsed for epoch 13: 7.484767913818359
# Time elapsed for epoch 14: 6.708386182785034
# Time elapsed for epoch 15: 6.856122016906738
# Time elapsed for epoch 16: 6.6266491413116455
# Time elapsed for epoch 17: 6.603224039077759
# Time elapsed for epoch 18: 6.83365797996521
# Time elapsed for epoch 19: 6.648807764053345

# %%
doc_id = np.random.randint(models[0].docvecs.count)  # Pick random doc; re-run cell for more examples
listing = sentences[doc_id].tags[0]
# advert = sentences[doc_id].tags[1]
print('for doc %s...' % listing, doc_id)
for model in models:
    inferred_docvec = model.infer_vector(sentences[doc_id].words)
    print('%s:\n %s' % (model, model.docvecs.most_similar([inferred_docvec], topn=3)))
# Out:
# for doc flatmate... 0
# Doc2Vec(dbow,d100,n5,mc2,s0.001,t4):
#  [('flatmate', 0.8741031289100647), ('landlord', 0.376987099647522), ('agent', 0.32483014464378357)]
# Doc2Vec(dm/m,d100,n5,w10,mc2,s0.001,t4):
#  [('landlord', 0.6521680355072021), ('flatmate', 0.6352423429489136), ('agent', 0.6119513511657715)]

# %%
t = models[1]
inf = t.infer_vector(sentences[doc_id].words, steps=100, alpha=0.025)
# print(t['LISTING_20671'])
# print(inf)
# t.docvecs.similarity('flatmate',listing)
t.docvecs.most_similar([t[listing]])
t.docvecs.doctags
# Out:
# {'LISTING_0': Doctag(offset=0, word_count=66, doc_count=1),
#  'agent': Doctag(offset=1, word_count=916267, doc_count=8702),
#  'LISTING_1': Doctag(offset=2, word_count=108, doc_count=1),
#  'landlord': Doctag(offset=3, word_count=1244450, doc_count=10004),
#  'LISTING_2': Doctag(offset=4, word_count=23, doc_count=1),
#  'LISTING_3': Doctag(offset=5, word_count=159, doc_count=1),
#  'flatmate': Doctag(offset=6, word_count=1291619, doc_count=9096),
#  'LISTING_4': Doctag(offset=7, word_count=151, doc_count=1),
#  'LISTING_5': Doctag(offset=8, word_count=48, doc_count=1),
#  'LISTING_6': Doctag(offset=9, word_count=117, doc_count=1),
#  'LISTING_7': Doctag(offset=10, word_count=71, doc_count=1),
#  'LISTING_8': Doctag(offset=11, word_count=38, doc_count=1),
#  'LISTING_9': Doctag(offset=12, word_count=125, doc_count=1),
#  'LISTING_10': Doctag(offset=13, word_count=80, doc_count=1),
#  'LISTING_11': Doctag(offset=14, word_count=57, doc_count=1),
#  'LISTING_12': Doctag(offset=15, word_count=60, doc_count=1),
#  'LISTING_13': Doctag(offset=16, word_count=66, doc_count=1),
#  'LISTING_14': Doctag(offset=17, word_count=80, doc_count=1),
#  'LISTING_15': Doctag(offset=18, word_count=139, doc_count=1),
#  'LISTING_16': Doctag(offset=19, word_count=66, doc_count=1),
#  'LISTING_17': Doctag(offset=20, word_count=83, doc_count=1),
#  'LISTING_18': Doctag(offset=21, word_count=139, doc_count=1),
#  'LISTING_19': Doctag(offset=22, word_count=47, doc_count=1),
#  'LISTING_20': Doctag(offset=23, word_count=102, doc_count=1),
#  'LISTING_21': Doctag(offset=24, word_count=91, doc_count=1),
#  'LISTING_22': Doctag(offset=25, word_count=124, doc_count=1),
#  'LISTING_23': Doctag(offset=26, word_count=53, doc_count=1),
#  'LISTING_24': Doctag(offset=27, word_count=148, doc_count=1),
#  'LISTING_25': Doctag(offset=28, word_count=148, doc_count=1),
#  'LISTING_26': Doctag(offset=29, word_count=155, doc_count=1),
#  'LISTING_27': Doctag(offset=30, word_count=121, doc_count=1),
#  'LISTING_28': Doctag(offset=31, word_count=94, doc_count=1),
#  'LISTING_29': Doctag(offset=32, word_count=42, doc_count=1),
#  'LISTING_30': Doctag(offset=33, word_count=34, doc_count=1),
#  'LISTING_31': Doctag(offset=34, word_count=107, doc_count=1),
#  'LISTING_32': Doctag(offset=35, word_count=59, doc_count=1),
#  'LISTING_33': Doctag(offset=36, word_count=272, doc_count=1),
#  'LISTING_34': Doctag(offset=37, word_count=292, doc_count=1),
#  'LISTING_35': Doctag(offset=38, word_count=70, doc_count=1),
#  'LISTING_36': Doctag(offset=39, word_count=181, doc_count=1),
#  'LISTING_37': Doctag(offset=40, word_count=66, doc_count=1),
#  'LISTING_38': Doctag(offset=41, word_count=172, doc_count=1),
#  'LISTING_39': Doctag(offset=42, word_count=153, doc_count=1),
#  'LISTING_40': Doctag(offset=43, word_count=98, doc_count=1),
#  'LISTING_41': Doctag(offset=44, word_count=166, doc_count=1),
#  'LISTING_42': Doctag(offset=45, word_count=68, doc_count=1),
#  'LISTING_43': Doctag(offset=46, word_count=80, doc_count=1),
#  'LISTING_44': Doctag(offset=47, word_count=202, doc_count=1),
#  'LISTING_45': Doctag(offset=48, word_count=79, doc_count=1),
#  'LISTING_46': Doctag(offset=49, word_count=135, doc_count=1),
#  'LISTING_47': Doctag(offset=50, word_count=80, doc_count=1),
#  'LISTING_48': Doctag(offset=51, word_count=130, doc_count=1),
#  'LISTING_49': Doctag(offset=52, word_count=157, doc_count=1),
#  'LISTING_50': Doctag(offset=53, word_count=130, doc_count=1),
#  'LISTING_51': Doctag(offset=54, word_count=51, doc_count=1),
#  'LISTING_52': Doctag(offset=55, word_count=112, doc_count=1),
#  'LISTING_53': Doctag(offset=56, word_count=63, doc_count=1),
#  'LISTING_54': Doctag(offset=57, word_count=31, doc_count=1),
#  'LISTING_55': Doctag(offset=58, word_count=105, doc_count=1),
#  'LISTING_56': Doctag(offset=59, word_count=63, doc_count=1),
#  'LISTING_57': Doctag(offset=60, word_count=143, doc_count=1),
#  'LISTING_58': Doctag(offset=61, word_count=71, doc_count=1),
#  'LISTING_59': Doctag(offset=62, word_count=83, doc_count=1),
#  'LISTING_60': Doctag(offset=63, word_count=223, doc_count=1),
#  'LISTING_61': Doctag(offset=64, word_count=65, doc_count=1),
#  'LISTING_62': Doctag(offset=65, word_count=49, doc_count=1),
#  'LISTING_63': Doctag(offset=66, word_count=117, doc_count=1),
#  'LISTING_64': Doctag(offset=67, word_count=45, doc_count=1),
#  'LISTING_65': Doctag(offset=68, word_count=34, doc_count=1),
#  'LISTING_66': Doctag(offset=69, word_count=386, doc_count=1),
#  'LISTING_67': Doctag(offset=70, word_count=121, doc_count=1),
#  'LISTING_68': Doctag(offset=71, word_count=436, doc_count=1),
#  'LISTING_69': Doctag(offset=72, word_count=73, doc_count=1),
#  'LISTING_70': Doctag(offset=73, word_count=73, doc_count=1),
#  'LISTING_71': Doctag(offset=74, word_count=188, doc_count=1),
#  'LISTING_72': Doctag(offset=75, word_count=127, doc_count=1),
#  'LISTING_73': Doctag(offset=76, word_count=453, doc_count=1),
#  'LISTING_74': Doctag(offset=77, word_count=71, doc_count=1),
#  'LISTING_75': Doctag(offset=78, word_count=44, doc_count=1),
#  'LISTING_76': Doctag(offset=79, word_count=133, doc_count=1),
#  'LISTING_77': Doctag(offset=80, word_count=91, doc_count=1),
#  'LISTING_78': Doctag(offset=81, word_count=95, doc_count=1),
#  'LISTING_79': Doctag(offset=82, word_count=104, doc_count=1),
#  'LISTING_80': Doctag(offset=83, word_count=122, doc_count=1),
#  'LISTING_81': Doctag(offset=84, word_count=61, doc_count=1),
#  'LISTING_82': Doctag(offset=85, word_count=26, doc_count=1),
#  'LISTING_83': Doctag(offset=86, word_count=92, doc_count=1),
#  'LISTING_84': Doctag(offset=87, word_count=35, doc_count=1),
#  'LISTING_85': Doctag(offset=88, word_count=54, doc_count=1),
#  'LISTING_86': Doctag(offset=89, word_count=117, doc_count=1),
#  'LISTING_87': Doctag(offset=90, word_count=97, doc_count=1),
#  'LISTING_88': Doctag(offset=91, word_count=200, doc_count=1),
#  'LISTING_89': Doctag(offset=92, word_count=394, doc_count=1),
#  'LISTING_90': Doctag(offset=93, word_count=69, doc_count=1),
#  'LISTING_91': Doctag(offset=94, word_count=98, doc_count=1),
#  'LISTING_92': Doctag(offset=95, word_count=59, doc_count=1),
#  'LISTING_93': Doctag(offset=96, word_count=84, doc_count=1),
#  'LISTING_94': Doctag(offset=97, word_count=81, doc_count=1),
#  'LISTING_95': Doctag(offset=98, word_count=199, doc_count=1),
#  'LISTING_96': Doctag(offset=99, word_count=255, doc_count=1),
#  'LISTING_97': Doctag(offset=100, word_count=235, doc_count=1),
#  'LISTING_98': Doctag(offset=101, word_count=219, doc_count=1),
#  'LISTING_99': Doctag(offset=102, word_count=237, doc_count=1),
#  'LISTING_100': Doctag(offset=103, word_count=244, doc_count=1),
#  'LISTING_101': Doctag(offset=104, word_count=53, doc_count=1),
#  'LISTING_102': Doctag(offset=105, word_count=132, doc_count=1),
#  'LISTING_103': Doctag(offset=106, word_count=47, doc_count=1),
#  'LISTING_104': Doctag(offset=107, word_count=114, doc_count=1),
#  'LISTING_105': Doctag(offset=108, word_count=62, doc_count=1),
#  'LISTING_106': Doctag(offset=109, word_count=57, doc_count=1),
#  'LISTING_107': Doctag(offset=110, word_count=67, doc_count=1),
#  'LISTING_108': Doctag(offset=111, word_count=128, doc_count=1),
#  'LISTING_109': Doctag(offset=112, word_count=92, doc_count=1),
#  'LISTING_110': Doctag(offset=113, word_count=78, doc_count=1),
#  'LISTING_111': Doctag(offset=114, word_count=225, doc_count=1),
#  'LISTING_112': Doctag(offset=115, word_count=103, doc_count=1),
#  'LISTING_113': Doctag(offset=116, word_count=107, doc_count=1),
#  'LISTING_114': Doctag(offset=117, word_count=178, doc_count=1),
#  'LISTING_115': Doctag(offset=118, word_count=327, doc_count=1),
#  'LISTING_116': Doctag(offset=119, word_count=42, doc_count=1),
#  'LISTING_117': Doctag(offset=120, word_count=92, doc_count=1),
#  'LISTING_118': Doctag(offset=121, word_count=71, doc_count=1),
#  'LISTING_119': Doctag(offset=122, word_count=55, doc_count=1),
#  'LISTING_120': Doctag(offset=123, word_count=100, doc_count=1),
#  'LISTING_121': Doctag(offset=124, word_count=53, doc_count=1),
#  'LISTING_122': Doctag(offset=125, word_count=44, doc_count=1),
#  'LISTING_123': Doctag(offset=126, word_count=91, doc_count=1),
#  'LISTING_124': Doctag(offset=127, word_count=216, doc_count=1),
#  'LISTING_125': Doctag(offset=128, word_count=424, doc_count=1),
#  'LISTING_126': Doctag(offset=129, word_count=248, doc_count=1),
#  'LISTING_127': Doctag(offset=130, word_count=101, doc_count=1),
#  'LISTING_128': Doctag(offset=131, word_count=38, doc_count=1),
#  'LISTING_129': Doctag(offset=132, word_count=45, doc_count=1),
#  'LISTING_130': Doctag(offset=133, word_count=144, doc_count=1),
#  'LISTING_131': Doctag(offset=134, word_count=48, doc_count=1),
#  'LISTING_132': Doctag(offset=135, word_count=108, doc_count=1),
#  'LISTING_133': Doctag(offset=136, word_count=75, doc_count=1),
#  'LISTING_134': Doctag(offset=137, word_count=59, doc_count=1),
#  'LISTING_135': Doctag(offset=138, word_count=226, doc_count=1),
#  'LISTING_136': Doctag(offset=139, word_count=72, doc_count=1),
#  'LISTING_137': Doctag(offset=140, word_count=328, doc_count=1),
#  'LISTING_138': Doctag(offset=141, word_count=26, doc_count=1),
#  'LISTING_139': Doctag(offset=142, word_count=32, doc_count=1),
#  'LISTING_140': Doctag(offset=143, word_count=264, doc_count=1),
#  'LISTING_141': Doctag(offset=144, word_count=42, doc_count=1),
#  'LISTING_142': Doctag(offset=145, word_count=126, doc_count=1),
#  'LISTING_143': Doctag(offset=146, word_count=164, doc_count=1),
#  'LISTING_144': Doctag(offset=147, word_count=67, doc_count=1),
#  'LISTING_145': Doctag(offset=148, word_count=317, doc_count=1),
#  'LISTING_146': Doctag(offset=149, word_count=92, doc_count=1),
#  'LISTING_147': Doctag(offset=150, word_count=89, doc_count=1),
#  'LISTING_148': Doctag(offset=151, word_count=167, doc_count=1),
#  'LISTING_149': Doctag(offset=152, word_count=55, doc_count=1),
#  'LISTING_150': Doctag(offset=153, word_count=213, doc_count=1),
#  'LISTING_151': Doctag(offset=154, word_count=113, doc_count=1),
#  'LISTING_152': Doctag(offset=155, word_count=255, doc_count=1),
#  'LISTING_153': Doctag(offset=156, word_count=118, doc_count=1),
#  'LISTING_154': Doctag(offset=157, word_count=110, doc_count=1),
#  'LISTING_155': Doctag(offset=158, word_count=69, doc_count=1),
#  'LISTING_156': Doctag(offset=159, word_count=117, doc_count=1),
#  'LISTING_157': Doctag(offset=160, word_count=11, doc_count=1),
#  'LISTING_158': Doctag(offset=161, word_count=57, doc_count=1),
#  'LISTING_159': Doctag(offset=162, word_count=92, doc_count=1),
#  'LISTING_160': Doctag(offset=163, word_count=299, doc_count=1),
#  'LISTING_161': Doctag(offset=164, word_count=138, doc_count=1),
#  'LISTING_162': Doctag(offset=165, word_count=125, doc_count=1),
#  'LISTING_163': Doctag(offset=166, word_count=85, doc_count=1),
#  'LISTING_164': Doctag(offset=167, word_count=188, doc_count=1),
#  'LISTING_165': Doctag(offset=168, word_count=146, doc_count=1),
#  'LISTING_166': Doctag(offset=169, word_count=231, doc_count=1),
#  'LISTING_167': Doctag(offset=170, word_count=280, doc_count=1),
#  'LISTING_168': Doctag(offset=171, word_count=97, doc_count=1),
#  'LISTING_169': Doctag(offset=172, word_count=142, doc_count=1),
#  'LISTING_170': Doctag(offset=173, word_count=67, doc_count=1),
#  'LISTING_171': Doctag(offset=174, word_count=41, doc_count=1),
#  'LISTING_172': Doctag(offset=175, word_count=57, doc_count=1),
#  'LISTING_173': Doctag(offset=176, word_count=197, doc_count=1),
#  'LISTING_174': Doctag(offset=177, word_count=205, doc_count=1),
#  'LISTING_175': Doctag(offset=178, word_count=352, doc_count=1),
#  'LISTING_176': Doctag(offset=179, word_count=175, doc_count=1),
#  'LISTING_177': Doctag(offset=180, word_count=106, doc_count=1),
#  'LISTING_178': Doctag(offset=181, word_count=67, doc_count=1),
#  'LISTING_179': Doctag(offset=182, word_count=235, doc_count=1),
#  'LISTING_180': Doctag(offset=183, word_count=74, doc_count=1),
#  'LISTING_181': Doctag(offset=184, word_count=265, doc_count=1),
#  'LISTING_182': Doctag(offset=185, word_count=196, doc_count=1),
#  'LISTING_183': Doctag(offset=186, word_count=238, doc_count=1),
#  'LISTING_184': Doctag(offset=187, word_count=185, doc_count=1),
#  'LISTING_185': Doctag(offset=188, word_count=11, doc_count=1),
#  'LISTING_186': Doctag(offset=189, word_count=134, doc_count=1),
#  'LISTING_187': Doctag(offset=190, word_count=353, doc_count=1),
#  'LISTING_188': Doctag(offset=191, word_count=60, doc_count=1),
#  'LISTING_189': Doctag(offset=192, word_count=69, doc_count=1),
#  'LISTING_190': Doctag(offset=193, word_count=92, doc_count=1),
#  'LISTING_191': Doctag(offset=194, word_count=48, doc_count=1),
#  'LISTING_192': Doctag(offset=195, word_count=73, doc_count=1),
#  'LISTING_193': Doctag(offset=196, word_count=69, doc_count=1),
#  'LISTING_194': Doctag(offset=197, word_count=205, doc_count=1),
#  'LISTING_195': Doctag(offset=198, word_count=203, doc_count=1),
#  'LISTING_196': Doctag(offset=199, word_count=166, doc_count=1),
#  'LISTING_197': Doctag(offset=200, word_count=98, doc_count=1),
#  'LISTING_198': Doctag(offset=201, word_count=99, doc_count=1),
#  'LISTING_199': Doctag(offset=202, word_count=60, doc_count=1),
#  'LISTING_200': Doctag(offset=203, word_count=49, doc_count=1),
#  'LISTING_201': Doctag(offset=204, word_count=104, doc_count=1),
#  'LISTING_202': Doctag(offset=205, word_count=111, doc_count=1),
#  'LISTING_203': Doctag(offset=206, word_count=99, doc_count=1),
#  'LISTING_204': Doctag(offset=207, word_count=95, doc_count=1),
#  'LISTING_205': Doctag(offset=208, word_count=61, doc_count=1),
#  'LISTING_206': Doctag(offset=209, word_count=346, doc_count=1),
#  'LISTING_207': Doctag(offset=210, word_count=103, doc_count=1),
#  'LISTING_208': Doctag(offset=211, word_count=168, doc_count=1),
#  'LISTING_209': Doctag(offset=212, word_count=98, doc_count=1),
#  'LISTING_210': Doctag(offset=213, word_count=140, doc_count=1),
#  'LISTING_211': Doctag(offset=214, word_count=81, doc_count=1),
#  'LISTING_212': Doctag(offset=215, word_count=126, doc_count=1),
#  'LISTING_213': Doctag(offset=216, word_count=179, doc_count=1),
#  'LISTING_214': Doctag(offset=217, word_count=91, doc_count=1),
#  'LISTING_215': Doctag(offset=218, word_count=71, doc_count=1),
#  'LISTING_216': Doctag(offset=219, word_count=56, doc_count=1),
#  'LISTING_217': Doctag(offset=220, word_count=155, doc_count=1),
#  'LISTING_218': Doctag(offset=221, word_count=115, doc_count=1),
#  'LISTING_219': Doctag(offset=222, word_count=37, doc_count=1),
#  'LISTING_220': Doctag(offset=223, word_count=74, doc_count=1),
#  'LISTING_221': Doctag(offset=224, word_count=139, doc_count=1),
#  'LISTING_222': Doctag(offset=225, word_count=113, doc_count=1),
#  'LISTING_223': Doctag(offset=226, word_count=150, doc_count=1),
#  'LISTING_224': Doctag(offset=227, word_count=150, doc_count=1),
#  'LISTING_225': Doctag(offset=228, word_count=40, doc_count=1),
#  'LISTING_226': Doctag(offset=229, word_count=82, doc_count=1),
#  'LISTING_227': Doctag(offset=230, word_count=466, doc_count=1),
#  'LISTING_228': Doctag(offset=231, word_count=167, doc_count=1),
#  'LISTING_229': Doctag(offset=232, word_count=38, doc_count=1),
#  'LISTING_230': Doctag(offset=233, word_count=39, doc_count=1),
#  'LISTING_231': Doctag(offset=234, word_count=182, doc_count=1),
#  'LISTING_232': Doctag(offset=235, word_count=182, doc_count=1),
#  'LISTING_233': Doctag(offset=236, word_count=104, doc_count=1),
#  'LISTING_234': Doctag(offset=237, word_count=150, doc_count=1),
#  'LISTING_235': Doctag(offset=238, word_count=160, doc_count=1),
#  'LISTING_236': Doctag(offset=239, word_count=82, doc_count=1),
#  'LISTING_237': Doctag(offset=240, word_count=102, doc_count=1),
#  'LISTING_238': Doctag(offset=241, word_count=143, doc_count=1),
#  'LISTING_239': Doctag(offset=242, word_count=139, doc_count=1),
#  'LISTING_240': Doctag(offset=243, word_count=190, doc_count=1),
#  'LISTING_241': Doctag(offset=244, word_count=199, doc_count=1),
#  'LISTING_242': Doctag(offset=245, word_count=372, doc_count=1),
#  'LISTING_243': Doctag(offset=246, word_count=85, doc_count=1),
#  'LISTING_244': Doctag(offset=247, word_count=224, doc_count=1),
#  'LISTING_245': Doctag(offset=248, word_count=398, doc_count=1),
#  'LISTING_246': Doctag(offset=249, word_count=75, doc_count=1),
#  'LISTING_247': Doctag(offset=250, word_count=253, doc_count=1),
#  'LISTING_248': Doctag(offset=251, word_count=71, doc_count=1),
#  'LISTING_249': Doctag(offset=252, word_count=121, doc_count=1),
#  'LISTING_250': Doctag(offset=253, word_count=150, doc_count=1),
#  'LISTING_251': Doctag(offset=254, word_count=326, doc_count=1),
#  'LISTING_252': Doctag(offset=255, word_count=164, doc_count=1),
#  'LISTING_253': Doctag(offset=256, word_count=78, doc_count=1),
#  'LISTING_254': Doctag(offset=257, word_count=72, doc_count=1),
#  'LISTING_255': Doctag(offset=258, word_count=197, doc_count=1),
#  'LISTING_256': Doctag(offset=259, word_count=290, doc_count=1),
#  'LISTING_257': Doctag(offset=260, word_count=58, doc_count=1),
#  'LISTING_258': Doctag(offset=261, word_count=40, doc_count=1),
#  'LISTING_259': Doctag(offset=262, word_count=189, doc_count=1),
#  'LISTING_260': Doctag(offset=263, word_count=119, doc_count=1),
#  'LISTING_261': Doctag(offset=264, word_count=50, doc_count=1),
#  'LISTING_262': Doctag(offset=265, word_count=48, doc_count=1),
#  'LISTING_263': Doctag(offset=266, word_count=285, doc_count=1),
#  'LISTING_264': Doctag(offset=267, word_count=106, doc_count=1),
#  'LISTING_265': Doctag(offset=268, word_count=155, doc_count=1),
#  'LISTING_266': Doctag(offset=269, word_count=258, doc_count=1),
#  'LISTING_267': Doctag(offset=270, word_count=48, doc_count=1),
#  'LISTING_268': Doctag(offset=271, word_count=54, doc_count=1),
#  'LISTING_269': Doctag(offset=272, word_count=133, doc_count=1),
#  'LISTING_270': Doctag(offset=273, word_count=159, doc_count=1),
#  'LISTING_271': Doctag(offset=274, word_count=95, doc_count=1),
#  'LISTING_272': Doctag(offset=275, word_count=69, doc_count=1),
#  'LISTING_273': Doctag(offset=276, word_count=109, doc_count=1),
#  'LISTING_274': Doctag(offset=277, word_count=19, doc_count=1),
#  'LISTING_275': Doctag(offset=278, word_count=42, doc_count=1),
#  'LISTING_276': Doctag(offset=279, word_count=90, doc_count=1),
#  'LISTING_277': Doctag(offset=280, word_count=219, doc_count=1),
#  'LISTING_278': Doctag(offset=281, word_count=92, doc_count=1),
#  'LISTING_279': Doctag(offset=282, word_count=49, doc_count=1),
#  'LISTING_280': Doctag(offset=283, word_count=173, doc_count=1),
#  'LISTING_281': Doctag(offset=284, word_count=130, doc_count=1),
#  'LISTING_282': Doctag(offset=285, word_count=114, doc_count=1),
#  'LISTING_283': Doctag(offset=286, word_count=79, doc_count=1),
#  'LISTING_284': Doctag(offset=287, word_count=57, doc_count=1),
#  'LISTING_285': Doctag(offset=288, word_count=51, doc_count=1),
#  'LISTING_286': Doctag(offset=289, word_count=223, doc_count=1),
#  'LISTING_287': Doctag(offset=290, word_count=126, doc_count=1),
#  'LISTING_288': Doctag(offset=291, word_count=229, doc_count=1),
#  'LISTING_289': Doctag(offset=292, word_count=203, doc_count=1),
#  'LISTING_290': Doctag(offset=293, word_count=108, doc_count=1),
#  'LISTING_291': Doctag(offset=294, word_count=234, doc_count=1),
#  'LISTING_292': Doctag(offset=295, word_count=114, doc_count=1),
#  'LISTING_293': Doctag(offset=296, word_count=215, doc_count=1),
#  'LISTING_294': Doctag(offset=297, word_count=65, doc_count=1),
#  'LISTING_295': Doctag(offset=298, word_count=20, doc_count=1),
#  'LISTING_296': Doctag(offset=299, word_count=212, doc_count=1),
#  'LISTING_297': Doctag(offset=300, word_count=160, doc_count=1),
#  'LISTING_298': Doctag(offset=301, word_count=231, doc_count=1),
#  'LISTING_299': Doctag(offset=302, word_count=162, doc_count=1),
#  'LISTING_300': Doctag(offset=303, word_count=96, doc_count=1),
#  'LISTING_301': Doctag(offset=304, word_count=62, doc_count=1),
#  'LISTING_302': Doctag(offset=305, word_count=72, doc_count=1),
#  'LISTING_303': Doctag(offset=306, word_count=67, doc_count=1),
#  'LISTING_304': Doctag(offset=307, word_count=90, doc_count=1),
#  'LISTING_305': Doctag(offset=308, word_count=99, doc_count=1),
#  'LISTING_306': Doctag(offset=309, word_count=123, doc_count=1),
#  'LISTING_307': Doctag(offset=310, word_count=95, doc_count=1),
#  'LISTING_308': Doctag(offset=311, word_count=102, doc_count=1),
#  'LISTING_309': Doctag(offset=312, word_count=88, doc_count=1),
#  'LISTING_310': Doctag(offset=313, word_count=142, doc_count=1),
#  'LISTING_311': Doctag(offset=314, word_count=172, doc_count=1),
#  'LISTING_312': Doctag(offset=315, word_count=111, doc_count=1),
#  'LISTING_313': Doctag(offset=316, word_count=89, doc_count=1),
#  'LISTING_314': Doctag(offset=317, word_count=176, doc_count=1),
#  'LISTING_315': Doctag(offset=318, word_count=149, doc_count=1),
#  'LISTING_316': Doctag(offset=319, word_count=45, doc_count=1),
#  'LISTING_317': Doctag(offset=320, word_count=145, doc_count=1),
#  'LISTING_318': Doctag(offset=321, word_count=165, doc_count=1),
#  'LISTING_319': Doctag(offset=322, word_count=79, doc_count=1),
#  'LISTING_320': Doctag(offset=323, word_count=199, doc_count=1),
#  'LISTING_321': Doctag(offset=324, word_count=113, doc_count=1),
#  'LISTING_322': Doctag(offset=325, word_count=87, doc_count=1),
#  'LISTING_323': Doctag(offset=326, word_count=132, doc_count=1),
#  'LISTING_324': Doctag(offset=327, word_count=297, doc_count=1),
#  'LISTING_325': Doctag(offset=328, word_count=176, doc_count=1),
#  'LISTING_326': Doctag(offset=329, word_count=210, doc_count=1),
#  'LISTING_327': Doctag(offset=330, word_count=426, doc_count=1),
#  'LISTING_328': Doctag(offset=331, word_count=82, doc_count=1),
#  'LISTING_329': Doctag(offset=332, word_count=232, doc_count=1),
#  'LISTING_330': Doctag(offset=333, word_count=223, doc_count=1),
#  'LISTING_331': Doctag(offset=334, word_count=260, doc_count=1),
#  'LISTING_332': Doctag(offset=335, word_count=215, doc_count=1),
#  'LISTING_333': Doctag(offset=336, word_count=98, doc_count=1),
#  'LISTING_334': Doctag(offset=337, word_count=158, doc_count=1),
#  'LISTING_335': Doctag(offset=338, word_count=198, doc_count=1),
#  'LISTING_336': Doctag(offset=339, word_count=90, doc_count=1),
#  'LISTING_337': Doctag(offset=340, word_count=109, doc_count=1),
#  'LISTING_338': Doctag(offset=341, word_count=74, doc_count=1),
#  'LISTING_339': Doctag(offset=342, word_count=91, doc_count=1),
#  'LISTING_340': Doctag(offset=343, word_count=121, doc_count=1),
#  'LISTING_341': Doctag(offset=344, word_count=31, doc_count=1),
#  'LISTING_342': Doctag(offset=345, word_count=53, doc_count=1),
#  'LISTING_343': Doctag(offset=346, word_count=62, doc_count=1),
#  'LISTING_344': Doctag(offset=347, word_count=136, doc_count=1),
#  'LISTING_345': Doctag(offset=348, word_count=95, doc_count=1),
#  'LISTING_346': Doctag(offset=349, word_count=34, doc_count=1),
#  'LISTING_347': Doctag(offset=350, word_count=87, doc_count=1),
#  'LISTING_348': Doctag(offset=351, word_count=313, doc_count=1),
#  'LISTING_349': Doctag(offset=352, word_count=51, doc_count=1),
#  'LISTING_350': Doctag(offset=353, word_count=284, doc_count=1),
#  'LISTING_351': Doctag(offset=354, word_count=127, doc_count=1),
#  'LISTING_352': Doctag(offset=355, word_count=23, doc_count=1),
#  'LISTING_353': Doctag(offset=356, word_count=34, doc_count=1),
#  'LISTING_354': Doctag(offset=357, word_count=54, doc_count=1),
#  'LISTING_355': Doctag(offset=358, word_count=173, doc_count=1),
#  'LISTING_356': Doctag(offset=359, word_count=138, doc_count=1),
#  'LISTING_357': Doctag(offset=360, word_count=71, doc_count=1),
#  'LISTING_358': Doctag(offset=361, word_count=278, doc_count=1),
#  'LISTING_359': Doctag(offset=362, word_count=386, doc_count=1),
#  'LISTING_360': Doctag(offset=363, word_count=118, doc_count=1),
#  'LISTING_361': Doctag(offset=364, word_count=47, doc_count=1),
#  'LISTING_362': Doctag(offset=365, word_count=212, doc_count=1),
#  'LISTING_363': Doctag(offset=366, word_count=223, doc_count=1),
#  'LISTING_364': Doctag(offset=367, word_count=601, doc_count=1),
#  'LISTING_365': Doctag(offset=368, word_count=164, doc_count=1),
#  'LISTING_366': Doctag(offset=369, word_count=75, doc_count=1),
#  'LISTING_367': Doctag(offset=370, word_count=142, doc_count=1),
#  'LISTING_368': Doctag(offset=371, word_count=120, doc_count=1),
#  'LISTING_369': Doctag(offset=372, word_count=338, doc_count=1),
#  'LISTING_370': Doctag(offset=373, word_count=296, doc_count=1),
#  'LISTING_371': Doctag(offset=374, word_count=81, doc_count=1),
#  'LISTING_372': Doctag(offset=375, word_count=141, doc_count=1),
#  'LISTING_373': Doctag(offset=376, word_count=106, doc_count=1),
#  'LISTING_374': Doctag(offset=377, word_count=278, doc_count=1),
#  'LISTING_375': Doctag(offset=378, word_count=161, doc_count=1),
#  'LISTING_376': Doctag(offset=379, word_count=76, doc_count=1),
#  'LISTING_377': Doctag(offset=380, word_count=94, doc_count=1),
#  'LISTING_378': Doctag(offset=381, word_count=235, doc_count=1),
#  'LISTING_379': Doctag(offset=382, word_count=94, doc_count=1),
#  'LISTING_380': Doctag(offset=383, word_count=189, doc_count=1),
#  'LISTING_381': Doctag(offset=384, word_count=73, doc_count=1),
#  'LISTING_382': Doctag(offset=385, word_count=177, doc_count=1),
#  'LISTING_383': Doctag(offset=386, word_count=180, doc_count=1),
#  'LISTING_384': Doctag(offset=387, word_count=201, doc_count=1),
#  'LISTING_385': Doctag(offset=388, word_count=282, doc_count=1),
#  'LISTING_386': Doctag(offset=389, word_count=41, doc_count=1),
#  'LISTING_387': Doctag(offset=390, word_count=88, doc_count=1),
#  'LISTING_388': Doctag(offset=391, word_count=34, doc_count=1),
#  'LISTING_389': Doctag(offset=392, word_count=183, doc_count=1),
#  'LISTING_390': Doctag(offset=393, word_count=317, doc_count=1),
#  'LISTING_391': Doctag(offset=394, word_count=238, doc_count=1),
#  'LISTING_392': Doctag(offset=395, word_count=155, doc_count=1),
#  'LISTING_393': Doctag(offset=396, word_count=251, doc_count=1),
#  'LISTING_394': Doctag(offset=397, word_count=48, doc_count=1),
#  'LISTING_395': Doctag(offset=398, word_count=288, doc_count=1),
#  'LISTING_396': Doctag(offset=399, word_count=155, doc_count=1),
#  'LISTING_397': Doctag(offset=400, word_count=263, doc_count=1),
#  'LISTING_398': Doctag(offset=401, word_count=75, doc_count=1),
#  'LISTING_399': Doctag(offset=402, word_count=118, doc_count=1),
#  'LISTING_400': Doctag(offset=403, word_count=95, doc_count=1),
#  'LISTING_401': Doctag(offset=404, word_count=140, doc_count=1),
#  'LISTING_402': Doctag(offset=405, word_count=23, doc_count=1),
#  'LISTING_403': Doctag(offset=406, word_count=113, doc_count=1),
#  'LISTING_404': Doctag(offset=407, word_count=68, doc_count=1),
#  'LISTING_405': Doctag(offset=408, word_count=250, doc_count=1),
#  'LISTING_406': Doctag(offset=409, word_count=59, doc_count=1),
#  'LISTING_407': Doctag(offset=410, word_count=56, doc_count=1),
#  'LISTING_408': Doctag(offset=411, word_count=185, doc_count=1),
#  'LISTING_409': Doctag(offset=412, word_count=326, doc_count=1),
#  'LISTING_410': Doctag(offset=413, word_count=172, doc_count=1),
#  'LISTING_411': Doctag(offset=414, word_count=79, doc_count=1),
#  'LISTING_412': Doctag(offset=415, word_count=33, doc_count=1),
#  'LISTING_413': Doctag(offset=416, word_count=285, doc_count=1),
#  'LISTING_414': Doctag(offset=417, word_count=71, doc_count=1),
#  'LISTING_415': Doctag(offset=418, word_count=35, doc_count=1),
#  'LISTING_416': Doctag(offset=419, word_count=242, doc_count=1),
#  'LISTING_417': Doctag(offset=420, word_count=49, doc_count=1),
#  'LISTING_418': Doctag(offset=421, word_count=29, doc_count=1),
#  'LISTING_419': Doctag(offset=422, word_count=267, doc_count=1),
#  'LISTING_420': Doctag(offset=423, word_count=264, doc_count=1),
#  'LISTING_421': Doctag(offset=424, word_count=99, doc_count=1),
#  'LISTING_422': Doctag(offset=425, word_count=68, doc_count=1),
#  'LISTING_423': Doctag(offset=426, word_count=128, doc_count=1),
#  'LISTING_424': Doctag(offset=427, word_count=87, doc_count=1),
#  'LISTING_425': Doctag(offset=428, word_count=92, doc_count=1),
#  'LISTING_426': Doctag(offset=429, word_count=72, doc_count=1),
#  'LISTING_427': Doctag(offset=430, word_count=157, doc_count=1),
#  'LISTING_428': Doctag(offset=431, word_count=66, doc_count=1),
#  'LISTING_429': Doctag(offset=432, word_count=139, doc_count=1),
#  'LISTING_430': Doctag(offset=433, word_count=59, doc_count=1),
#  'LISTING_431': Doctag(offset=434, word_count=167, doc_count=1),
#  'LISTING_432': Doctag(offset=435, word_count=69, doc_count=1),
#  'LISTING_433': Doctag(offset=436, word_count=290, doc_count=1),
#  'LISTING_434': Doctag(offset=437, word_count=258, doc_count=1),
#  'LISTING_435': Doctag(offset=438, word_count=215, doc_count=1),
#  'LISTING_436': Doctag(offset=439, word_count=57, doc_count=1),
#  'LISTING_437': Doctag(offset=440, word_count=182, doc_count=1),
#  'LISTING_438': Doctag(offset=441, word_count=132, doc_count=1),
#  'LISTING_439': Doctag(offset=442, word_count=119, doc_count=1),
#  'LISTING_440': Doctag(offset=443, word_count=245, doc_count=1),
#  'LISTING_441': Doctag(offset=444, word_count=131, doc_count=1),
#  'LISTING_442': Doctag(offset=445, word_count=148, doc_count=1),
#  'LISTING_443': Doctag(offset=446, word_count=33, doc_count=1),
#  'LISTING_444': Doctag(offset=447, word_count=162, doc_count=1),
#  'LISTING_445': Doctag(offset=448, word_count=111, doc_count=1),
#  'LISTING_446': Doctag(offset=449, word_count=128, doc_count=1),
#  'LISTING_447': Doctag(offset=450, word_count=175, doc_count=1),
#  'LISTING_448': Doctag(offset=451, word_count=137, doc_count=1),
#  'LISTING_449': Doctag(offset=452, word_count=274, doc_count=1),
#  'LISTING_450': Doctag(offset=453, word_count=180, doc_count=1),
#  'LISTING_451': Doctag(offset=454, word_count=62, doc_count=1),
#  'LISTING_452': Doctag(offset=455, word_count=184, doc_count=1),
#  'LISTING_453': Doctag(offset=456, word_count=179, doc_count=1),
#  'LISTING_454': Doctag(offset=457, word_count=52, doc_count=1),
#  'LISTING_455': Doctag(offset=458, word_count=122, doc_count=1),
#  'LISTING_456': Doctag(offset=459, word_count=83, doc_count=1),
#  'LISTING_457': Doctag(offset=460, word_count=74, doc_count=1),
#  'LISTING_458': Doctag(offset=461, word_count=124, doc_count=1),
#  'LISTING_459': Doctag(offset=462, word_count=100, doc_count=1),
#  'LISTING_460': Doctag(offset=463, word_count=139, doc_count=1),
#  'LISTING_461': Doctag(offset=464, word_count=112, doc_count=1),
#  'LISTING_462': Doctag(offset=465, word_count=204, doc_count=1),
#  'LISTING_463': Doctag(offset=466, word_count=185, doc_count=1),
#  'LISTING_464': Doctag(offset=467, word_count=272, doc_count=1),
#  'LISTING_465': Doctag(offset=468, word_count=72, doc_count=1),
#  'LISTING_466': Doctag(offset=469, word_count=46, doc_count=1),
#  'LISTING_467': Doctag(offset=470, word_count=47, doc_count=1),
#  'LISTING_468': Doctag(offset=471, word_count=117, doc_count=1),
#  'LISTING_469': Doctag(offset=472, word_count=76, doc_count=1),
#  'LISTING_470': Doctag(offset=473, word_count=50, doc_count=1),
#  'LISTING_471': Doctag(offset=474, word_count=157, doc_count=1),
#  'LISTING_472': Doctag(offset=475, word_count=34, doc_count=1),
#  'LISTING_473': Doctag(offset=476, word_count=165, doc_count=1),
#  'LISTING_474': Doctag(offset=477, word_count=69, doc_count=1),
#  'LISTING_475': Doctag(offset=478, word_count=74, doc_count=1),
#  'LISTING_476': Doctag(offset=479, word_count=55, doc_count=1),
#  'LISTING_477': Doctag(offset=480, word_count=191, doc_count=1),
#  'LISTING_478': Doctag(offset=481, word_count=191, doc_count=1),
#  'LISTING_479': Doctag(offset=482, word_count=129, doc_count=1),
#  'LISTING_480': Doctag(offset=483, word_count=211, doc_count=1),
#  'LISTING_481': Doctag(offset=484, word_count=28, doc_count=1),
#  'LISTING_482': Doctag(offset=485, word_count=151, doc_count=1),
#  'LISTING_483': Doctag(offset=486, word_count=45, doc_count=1),
#  'LISTING_484': Doctag(offset=487, word_count=230, doc_count=1),
#  'LISTING_485': Doctag(offset=488, word_count=65, doc_count=1),
#  'LISTING_486': Doctag(offset=489, word_count=67, doc_count=1),
#  'LISTING_487': Doctag(offset=490, word_count=33, doc_count=1),
#  'LISTING_488': Doctag(offset=491, word_count=69, doc_count=1),
#  'LISTING_489': Doctag(offset=492, word_count=244, doc_count=1),
#  'LISTING_490': Doctag(offset=493, word_count=110, doc_count=1),
#  'LISTING_491': Doctag(offset=494, word_count=390, doc_count=1),
#  'LISTING_492': Doctag(offset=495, word_count=36, doc_count=1),
#  'LISTING_493': Doctag(offset=496, word_count=90, doc_count=1),
#  'LISTING_494': Doctag(offset=497, word_count=423, doc_count=1),
#  'LISTING_495': Doctag(offset=498, word_count=192, doc_count=1),
#  'LISTING_496': Doctag(offset=499, word_count=270, doc_count=1),
#  'LISTING_497': Doctag(offset=500, word_count=172, doc_count=1),
#  'LISTING_498': Doctag(offset=501, word_count=32, doc_count=1),
#  'LISTING_499': Doctag(offset=502, word_count=201, doc_count=1),
#  'LISTING_500': Doctag(offset=503, word_count=37, doc_count=1),
#  'LISTING_501': Doctag(offset=504, word_count=55, doc_count=1),
#  'LISTING_502': Doctag(offset=505, word_count=93, doc_count=1),
#  'LISTING_503': Doctag(offset=506, word_count=37, doc_count=1),
#  'LISTING_504': Doctag(offset=507, word_count=160, doc_count=1),
#  'LISTING_505': Doctag(offset=508, word_count=26, doc_count=1),
#  'LISTING_506': Doctag(offset=509, word_count=118, doc_count=1),
#  'LISTING_507': Doctag(offset=510, word_count=276, doc_count=1),
#  'LISTING_508': Doctag(offset=511, word_count=104, doc_count=1),
#  'LISTING_509': Doctag(offset=512, word_count=290, doc_count=1),
#  'LISTING_510': Doctag(offset=513, word_count=83, doc_count=1),
#  'LISTING_511': Doctag(offset=514, word_count=140, doc_count=1),
#  'LISTING_512': Doctag(offset=515, word_count=43, doc_count=1),
#  'LISTING_513': Doctag(offset=516, word_count=177, doc_count=1),
#  'LISTING_514': Doctag(offset=517, word_count=128, doc_count=1),
#  'LISTING_515': Doctag(offset=518, word_count=139, doc_count=1),
#  'LISTING_516': Doctag(offset=519, word_count=171, doc_count=1),
#  'LISTING_517': Doctag(offset=520, word_count=145, doc_count=1),
#  'LISTING_518': Doctag(offset=521, word_count=128, doc_count=1),
#  'LISTING_519': Doctag(offset=522, word_count=422, doc_count=1),
#  'LISTING_520': Doctag(offset=523, word_count=40, doc_count=1),
#  'LISTING_521': Doctag(offset=524, word_count=168, doc_count=1),
#  'LISTING_522': Doctag(offset=525, word_count=268, doc_count=1),
#  'LISTING_523': Doctag(offset=526, word_count=297, doc_count=1),
#  'LISTING_524': Doctag(offset=527, word_count=45, doc_count=1),
#  'LISTING_525': Doctag(offset=528, word_count=90, doc_count=1),
#  'LISTING_526': Doctag(offset=529, word_count=35, doc_count=1),
#  'LISTING_527': Doctag(offset=530, word_count=77, doc_count=1),
#  'LISTING_528': Doctag(offset=531, word_count=139, doc_count=1),
#  'LISTING_529': Doctag(offset=532, word_count=26, doc_count=1),
#  'LISTING_530': Doctag(offset=533, word_count=138, doc_count=1),
#  'LISTING_531': Doctag(offset=534, word_count=154, doc_count=1),
#  'LISTING_532': Doctag(offset=535, word_count=447, doc_count=1),
#  'LISTING_533': Doctag(offset=536, word_count=205, doc_count=1),
#  'LISTING_534': Doctag(offset=537, word_count=142, doc_count=1),
#  'LISTING_535': Doctag(offset=538, word_count=332, doc_count=1),
#  'LISTING_536': Doctag(offset=539, word_count=63, doc_count=1),
#  'LISTING_537': Doctag(offset=540, word_count=123, doc_count=1),
#  'LISTING_538': Doctag(offset=541, word_count=29, doc_count=1),
#  'LISTING_539': Doctag(offset=542, word_count=82, doc_count=1),
#  'LISTING_540': Doctag(offset=543, word_count=67, doc_count=1),
#  'LISTING_541': Doctag(offset=544, word_count=173, doc_count=1),
#  'LISTING_542': Doctag(offset=545, word_count=126, doc_count=1),
#  'LISTING_543': Doctag(offset=546, word_count=145, doc_count=1),
#  'LISTING_544': Doctag(offset=547, word_count=81, doc_count=1),
#  'LISTING_545': Doctag(offset=548, word_count=151, doc_count=1),
#  'LISTING_546': Doctag(offset=549, word_count=91, doc_count=1),
#  'LISTING_547': Doctag(offset=550, word_count=296, doc_count=1),
#  'LISTING_548': Doctag(offset=551, word_count=142, doc_count=1),
#  'LISTING_549': Doctag(offset=552, word_count=35, doc_count=1),
#  'LISTING_550': Doctag(offset=553, word_count=76, doc_count=1),
#  'LISTING_551': Doctag(offset=554, word_count=384, doc_count=1),
#  'LISTING_552': Doctag(offset=555, word_count=339, doc_count=1),
#  'LISTING_553': Doctag(offset=556, word_count=93, doc_count=1),
#  'LISTING_554': Doctag(offset=557, word_count=148, doc_count=1),
#  'LISTING_555': Doctag(offset=558, word_count=214, doc_count=1),
#  'LISTING_556': Doctag(offset=559, word_count=283, doc_count=1),
#  'LISTING_557': Doctag(offset=560, word_count=118, doc_count=1),
#  'LISTING_558': Doctag(offset=561, word_count=302, doc_count=1),
#  'LISTING_559': Doctag(offset=562, word_count=75, doc_count=1),
#  'LISTING_560': Doctag(offset=563, word_count=191, doc_count=1),
#  'LISTING_561': Doctag(offset=564, word_count=83, doc_count=1),
#  'LISTING_562': Doctag(offset=565, word_count=135, doc_count=1),
#  'LISTING_563': Doctag(offset=566, word_count=225, doc_count=1),
#  'LISTING_564': Doctag(offset=567, word_count=193, doc_count=1),
#  'LISTING_565': Doctag(offset=568, word_count=59, doc_count=1),
#  'LISTING_566': Doctag(offset=569, word_count=322, doc_count=1),
#  'LISTING_567': Doctag(offset=570, word_count=110, doc_count=1),
#  'LISTING_568': Doctag(offset=571, word_count=306, doc_count=1),
#  'LISTING_569': Doctag(offset=572, word_count=92, doc_count=1),
#  'LISTING_570': Doctag(offset=573, word_count=78, doc_count=1),
#  'LISTING_571': Doctag(offset=574, word_count=107, doc_count=1),
#  'LISTING_572': Doctag(offset=575, word_count=103, doc_count=1),
#  'LISTING_573': Doctag(offset=576, word_count=143, doc_count=1),
#  'LISTING_574': Doctag(offset=577, word_count=36, doc_count=1),
#  'LISTING_575': Doctag(offset=578, word_count=336, doc_count=1),
#  'LISTING_576': Doctag(offset=579, word_count=211, doc_count=1),
#  'LISTING_577': Doctag(offset=580, word_count=50, doc_count=1),
#  'LISTING_578': Doctag(offset=581, word_count=213, doc_count=1),
#  'LISTING_579': Doctag(offset=582, word_count=145, doc_count=1),
#  'LISTING_580': Doctag(offset=583, word_count=56, doc_count=1),
#  'LISTING_581': Doctag(offset=584, word_count=48, doc_count=1),
#  'LISTING_582': Doctag(offset=585, word_count=265, doc_count=1),
#  'LISTING_583': Doctag(offset=586, word_count=48, doc_count=1),
#  'LISTING_584': Doctag(offset=587, word_count=193, doc_count=1),
#  'LISTING_585': Doctag(offset=588, word_count=151, doc_count=1),
#  'LISTING_586': Doctag(offset=589, word_count=207, doc_count=1),
#  'LISTING_587': Doctag(offset=590, word_count=205, doc_count=1),
#  'LISTING_588': Doctag(offset=591, word_count=295, doc_count=1),
#  'LISTING_589': Doctag(offset=592, word_count=54, doc_count=1),
#  'LISTING_590': Doctag(offset=593, word_count=172, doc_count=1),
#  'LISTING_591': Doctag(offset=594, word_count=91, doc_count=1),
#  'LISTING_592': Doctag(offset=595, word_count=402, doc_count=1),
#  'LISTING_593': Doctag(offset=596, word_count=16, doc_count=1),
#  'LISTING_594': Doctag(offset=597, word_count=235, doc_count=1),
#  'LISTING_595': Doctag(offset=598, word_count=73, doc_count=1),
#  'LISTING_596': Doctag(offset=599, word_count=50, doc_count=1),
#  'LISTING_597': Doctag(offset=600, word_count=301, doc_count=1),
#  'LISTING_598': Doctag(offset=601, word_count=65, doc_count=1),
#  'LISTING_599': Doctag(offset=602, word_count=179, doc_count=1),
#  'LISTING_600': Doctag(offset=603, word_count=123, doc_count=1),
#  'LISTING_601': Doctag(offset=604, word_count=61, doc_count=1),
#  'LISTING_602': Doctag(offset=605, word_count=35, doc_count=1),
#  'LISTING_603': Doctag(offset=606, word_count=264, doc_count=1),
#  'LISTING_604': Doctag(offset=607, word_count=17, doc_count=1),
#  'LISTING_605': Doctag(offset=608, word_count=147, doc_count=1),
#  'LISTING_606': Doctag(offset=609, word_count=14, doc_count=1),
#  'LISTING_607': Doctag(offset=610, word_count=184, doc_count=1),
#  'LISTING_608': Doctag(offset=611, word_count=116, doc_count=1),
#  'LISTING_609': Doctag(offset=612, word_count=190, doc_count=1),
#  'LISTING_610': Doctag(offset=613, word_count=236, doc_count=1),
#  'LISTING_611': Doctag(offset=614, word_count=132, doc_count=1),
#  'LISTING_612': Doctag(offset=615, word_count=43, doc_count=1),
#  'LISTING_613': Doctag(offset=616, word_count=67, doc_count=1),
#  'LISTING_614': Doctag(offset=617, word_count=67, doc_count=1),
#  'LISTING_615': Doctag(offset=618, word_count=61, doc_count=1),
#  'LISTING_616': Doctag(offset=619, word_count=120, doc_count=1),
#  'LISTING_617': Doctag(offset=620, word_count=108, doc_count=1),
#  'LISTING_618': Doctag(offset=621, word_count=111, doc_count=1),
#  'LISTING_619': Doctag(offset=622, word_count=83, doc_count=1),
#  'LISTING_620': Doctag(offset=623, word_count=168, doc_count=1),
#  'LISTING_621': Doctag(offset=624, word_count=87, doc_count=1),
#  'LISTING_622': Doctag(offset=625, word_count=225, doc_count=1),
#  'LISTING_623': Doctag(offset=626, word_count=199, doc_count=1),
#  'LISTING_624': Doctag(offset=627, word_count=64, doc_count=1),
#  'LISTING_625': Doctag(offset=628, word_count=127, doc_count=1),
#  'LISTING_626': Doctag(offset=629, word_count=40, doc_count=1),
#  'LISTING_627': Doctag(offset=630, word_count=96, doc_count=1),
#  'LISTING_628': Doctag(offset=631, word_count=222, doc_count=1),
#  'LISTING_629': Doctag(offset=632, word_count=31, doc_count=1),
#  'LISTING_630': Doctag(offset=633, word_count=96, doc_count=1),
#  'LISTING_631': Doctag(offset=634, word_count=59, doc_count=1),
#  'LISTING_632': Doctag(offset=635, word_count=74, doc_count=1),
#  'LISTING_633': Doctag(offset=636, word_count=60, doc_count=1),
#  'LISTING_634': Doctag(offset=637, word_count=190, doc_count=1),
#  'LISTING_635': Doctag(offset=638, word_count=48, doc_count=1),
#  'LISTING_636': Doctag(offset=639, word_count=122, doc_count=1),
#  'LISTING_637': Doctag(offset=640, word_count=52, doc_count=1),
#  'LISTING_638': Doctag(offset=641, word_count=119, doc_count=1),
#  'LISTING_639': Doctag(offset=642, word_count=76, doc_count=1),
#  'LISTING_640': Doctag(offset=643, word_count=79, doc_count=1),
#  'LISTING_641': Doctag(offset=644, word_count=133, doc_count=1),
#  'LISTING_642': Doctag(offset=645, word_count=115, doc_count=1),
#  'LISTING_643': Doctag(offset=646, word_count=71, doc_count=1),
#  'LISTING_644': Doctag(offset=647, word_count=197, doc_count=1),
#  'LISTING_645': Doctag(offset=648, word_count=23, doc_count=1),
#  'LISTING_646': Doctag(offset=649, word_count=63, doc_count=1),
#  'LISTING_647': Doctag(offset=650, word_count=124, doc_count=1),
#  'LISTING_648': Doctag(offset=651, word_count=231, doc_count=1),
#  'LISTING_649': Doctag(offset=652, word_count=59, doc_count=1),
#  'LISTING_650': Doctag(offset=653, word_count=216, doc_count=1),
#  'LISTING_651': Doctag(offset=654, word_count=60, doc_count=1),
#  'LISTING_652': Doctag(offset=655, word_count=44, doc_count=1),
#  'LISTING_653': Doctag(offset=656, word_count=176, doc_count=1),
#  'LISTING_654': Doctag(offset=657, word_count=36, doc_count=1),
#  'LISTING_655': Doctag(offset=658, word_count=184, doc_count=1),
#  'LISTING_656': Doctag(offset=659, word_count=175, doc_count=1),
#  'LISTING_657': Doctag(offset=660, word_count=57, doc_count=1),
#  'LISTING_658': Doctag(offset=661, word_count=98, doc_count=1),
#  'LISTING_659': Doctag(offset=662, word_count=223, doc_count=1),
#  'LISTING_660': Doctag(offset=663, word_count=133, doc_count=1),
#  'LISTING_661': Doctag(offset=664, word_count=73, doc_count=1),
#  'LISTING_662': Doctag(offset=665, word_count=129, doc_count=1),
#  'LISTING_663': Doctag(offset=666, word_count=269, doc_count=1),
#  'LISTING_664': Doctag(offset=667, word_count=148, doc_count=1),
#  'LISTING_665': Doctag(offset=668, word_count=140, doc_count=1),
#  'LISTING_666': Doctag(offset=669, word_count=91, doc_count=1),
#  'LISTING_667': Doctag(offset=670, word_count=114, doc_count=1),
#  'LISTING_668': Doctag(offset=671, word_count=113, doc_count=1),
#  'LISTING_669': Doctag(offset=672, word_count=49, doc_count=1),
#  'LISTING_670': Doctag(offset=673, word_count=50, doc_count=1),
#  'LISTING_671': Doctag(offset=674, word_count=88, doc_count=1),
#  'LISTING_672': Doctag(offset=675, word_count=17, doc_count=1),
#  'LISTING_673': Doctag(offset=676, word_count=28, doc_count=1),
#  'LISTING_674': Doctag(offset=677, word_count=372, doc_count=1),
#  'LISTING_675': Doctag(offset=678, word_count=69, doc_count=1),
#  'LISTING_676': Doctag(offset=679, word_count=231, doc_count=1),
#  'LISTING_677': Doctag(offset=680, word_count=210, doc_count=1),
#  'LISTING_678': Doctag(offset=681, word_count=233, doc_count=1),
#  'LISTING_679': Doctag(offset=682, word_count=283, doc_count=1),
#  'LISTING_680': Doctag(offset=683, word_count=98, doc_count=1),
#  'LISTING_681': Doctag(offset=684, word_count=360, doc_count=1),
#  'LISTING_682': Doctag(offset=685, word_count=46, doc_count=1),
#  'LISTING_683': Doctag(offset=686, word_count=303, doc_count=1),
#  'LISTING_684': Doctag(offset=687, word_count=143, doc_count=1),
#  'LISTING_685': Doctag(offset=688, word_count=321, doc_count=1),
#  'LISTING_686': Doctag(offset=689, word_count=117, doc_count=1),
#  'LISTING_687': Doctag(offset=690, word_count=97, doc_count=1),
#  'LISTING_688': Doctag(offset=691, word_count=124, doc_count=1),
#  'LISTING_689': Doctag(offset=692, word_count=35, doc_count=1),
#  'LISTING_690': Doctag(offset=693, word_count=85, doc_count=1),
#  'LISTING_691': Doctag(offset=694, word_count=93, doc_count=1),
#  'LISTING_692': Doctag(offset=695, word_count=60, doc_count=1),
#  'LISTING_693': Doctag(offset=696, word_count=75, doc_count=1),
#  'LISTING_694': Doctag(offset=697, word_count=151, doc_count=1),
#  'LISTING_695': Doctag(offset=698, word_count=154, doc_count=1),
#  'LISTING_696': Doctag(offset=699, word_count=230, doc_count=1),
#  'LISTING_697': Doctag(offset=700, word_count=133, doc_count=1),
#  'LISTING_698': Doctag(offset=701, word_count=49, doc_count=1),
#  'LISTING_699': Doctag(offset=702, word_count=94, doc_count=1),
#  'LISTING_700': Doctag(offset=703, word_count=68, doc_count=1),
#  'LISTING_701': Doctag(offset=704, word_count=85, doc_count=1),
#  'LISTING_702': Doctag(offset=705, word_count=205, doc_count=1),
#  'LISTING_703': Doctag(offset=706, word_count=239, doc_count=1),
#  'LISTING_704': Doctag(offset=707, word_count=226, doc_count=1),
#  'LISTING_705': Doctag(offset=708, word_count=83, doc_count=1),
#  'LISTING_706': Doctag(offset=709, word_count=40, doc_count=1),
#  'LISTING_707': Doctag(offset=710, word_count=78, doc_count=1),
#  'LISTING_708': Doctag(offset=711, word_count=66, doc_count=1),
#  'LISTING_709': Doctag(offset=712, word_count=25, doc_count=1),
#  'LISTING_710': Doctag(offset=713, word_count=228, doc_count=1),
#  'LISTING_711': Doctag(offset=714, word_count=41, doc_count=1),
#  'LISTING_712': Doctag(offset=715, word_count=120, doc_count=1),
#  'LISTING_713': Doctag(offset=716, word_count=237, doc_count=1),
#  'LISTING_714': Doctag(offset=717, word_count=91, doc_count=1),
#  'LISTING_715': Doctag(offset=718, word_count=33, doc_count=1),
#  'LISTING_716': Doctag(offset=719, word_count=145, doc_count=1),
#  'LISTING_717': Doctag(offset=720, word_count=91, doc_count=1),
#  'LISTING_718': Doctag(offset=721, word_count=96, doc_count=1),
#  'LISTING_719': Doctag(offset=722, word_count=74, doc_count=1),
#  'LISTING_720': Doctag(offset=723, word_count=109, doc_count=1),
#  'LISTING_721': Doctag(offset=724, word_count=54, doc_count=1),
#  'LISTING_722': Doctag(offset=725, word_count=57, doc_count=1),
#  'LISTING_723': Doctag(offset=726, word_count=190, doc_count=1),
#  'LISTING_724': Doctag(offset=727, word_count=52, doc_count=1),
#  'LISTING_725': Doctag(offset=728, word_count=58, doc_count=1),
#  'LISTING_726': Doctag(offset=729, word_count=157, doc_count=1),
#  'LISTING_727': Doctag(offset=730, word_count=189, doc_count=1),
#  'LISTING_728': Doctag(offset=731, word_count=125, doc_count=1),
#  'LISTING_729': Doctag(offset=732, word_count=274, doc_count=1),
#  'LISTING_730': Doctag(offset=733, word_count=100, doc_count=1),
#  'LISTING_731': Doctag(offset=734, word_count=242, doc_count=1),
#  'LISTING_732': Doctag(offset=735, word_count=241, doc_count=1),
#  'LISTING_733': Doctag(offset=736, word_count=75, doc_count=1),
#  'LISTING_734': Doctag(offset=737, word_count=45, doc_count=1),
#  'LISTING_735': Doctag(offset=738, word_count=148, doc_count=1),
#  'LISTING_736': Doctag(offset=739, word_count=56, doc_count=1),
#  'LISTING_737': Doctag(offset=740, word_count=35, doc_count=1),
#  'LISTING_738': Doctag(offset=741, word_count=100, doc_count=1),
#  'LISTING_739': Doctag(offset=742, word_count=104, doc_count=1),
#  'LISTING_740': Doctag(offset=743, word_count=149, doc_count=1),
#  'LISTING_741': Doctag(offset=744, word_count=164, doc_count=1),
#  'LISTING_742': Doctag(offset=745, word_count=302, doc_count=1),
# ...
#  'LISTING_750': Doctag(offset=753, word_count=192, doc_count=1),
#  'LISTING_751': Doctag(offset=754, word_count=219, doc_count=1),
#  'LISTING_752': Doctag(offset=755, word_count=239, doc_count=1),
#  'LISTING_753': Doctag(offset=756, word_count=251, doc_count=1),
#  'LISTING_754': Doctag(offset=757, word_count=77, doc_count=1),
#  'LISTING_755': Doctag(offset=758, word_count=170, doc_count=1),
#  'LISTING_756': Doctag(offset=759, word_count=33, doc_count=1),
#  'LISTING_757': Doctag(offset=760, word_count=443, doc_count=1),
#  'LISTING_758': Doctag(offset=761, word_count=136, doc_count=1),
#  'LISTING_759': Doctag(offset=762, word_count=85, doc_count=1),
#  'LISTING_760': Doctag(offset=763, word_count=321, doc_count=1),
#  'LISTING_761': Doctag(offset=764, word_count=215, doc_count=1),
#  'LISTING_762': Doctag(offset=765, word_count=257, doc_count=1),
#  'LISTING_763': Doctag(offset=766, word_count=179, doc_count=1),
#  'LISTING_764': Doctag(offset=767, word_count=49, doc_count=1),
#  'LISTING_765': Doctag(offset=768, word_count=114, doc_count=1),
#  'LISTING_766': Doctag(offset=769, word_count=185, doc_count=1),
#  'LISTING_767': Doctag(offset=770, word_count=68, doc_count=1),
#  'LISTING_768': Doctag(offset=771, word_count=343, doc_count=1),
#  'LISTING_769': Doctag(offset=772, word_count=100, doc_count=1),
#  'LISTING_770': Doctag(offset=773, word_count=176, doc_count=1),
#  'LISTING_771': Doctag(offset=774, word_count=122, doc_count=1),
#  'LISTING_772': Doctag(offset=775, word_count=68, doc_count=1),
#  'LISTING_773': Doctag(offset=776, word_count=36, doc_count=1),
#  'LISTING_774': Doctag(offset=777, word_count=112, doc_count=1),
#  'LISTING_775': Doctag(offset=778, word_count=181, doc_count=1),
#  'LISTING_776': Doctag(offset=779, word_count=282, doc_count=1),
#  'LISTING_777': Doctag(offset=780, word_count=320, doc_count=1),
#  'LISTING_778': Doctag(offset=781, word_count=100, doc_count=1),
#  'LISTING_779': Doctag(offset=782, word_count=80, doc_count=1),
#  'LISTING_780': Doctag(offset=783, word_count=225, doc_count=1),
#  'LISTING_781': Doctag(offset=784, word_count=59, doc_count=1),
#  'LISTING_782': Doctag(offset=785, word_count=96, doc_count=1),
#  'LISTING_783': Doctag(offset=786, word_count=56, doc_count=1),
#  'LISTING_784': Doctag(offset=787, word_count=191, doc_count=1),
#  'LISTING_785': Doctag(offset=788, word_count=121, doc_count=1),
#  'LISTING_786': Doctag(offset=789, word_count=66, doc_count=1),
#  'LISTING_787': Doctag(offset=790, word_count=130, doc_count=1),
#  'LISTING_788': Doctag(offset=791, word_count=92, doc_count=1),
#  'LISTING_789': Doctag(offset=792, word_count=119, doc_count=1),
#  'LISTING_790': Doctag(offset=793, word_count=208, doc_count=1),
#  'LISTING_791': Doctag(offset=794, word_count=36, doc_count=1),
#  'LISTING_792': Doctag(offset=795, word_count=62, doc_count=1),
#  'LISTING_793': Doctag(offset=796, word_count=212, doc_count=1),
#  'LISTING_794': Doctag(offset=797, word_count=180, doc_count=1),
#  'LISTING_795': Doctag(offset=798, word_count=39, doc_count=1),
#  'LISTING_796': Doctag(offset=799, word_count=84, doc_count=1),
#  'LISTING_797': Doctag(offset=800, word_count=141, doc_count=1),
#  'LISTING_798': Doctag(offset=801, word_count=201, doc_count=1),
#  'LISTING_799': Doctag(offset=802, word_count=175, doc_count=1),
#  'LISTING_800': Doctag(offset=803, word_count=103, doc_count=1),
#  'LISTING_801': Doctag(offset=804, word_count=179, doc_count=1),
#  'LISTING_802': Doctag(offset=805, word_count=33, doc_count=1),
#  'LISTING_803': Doctag(offset=806, word_count=127, doc_count=1),
#  'LISTING_804': Doctag(offset=807, word_count=292, doc_count=1),
#  'LISTING_805': Doctag(offset=808, word_count=138, doc_count=1),
#  'LISTING_806': Doctag(offset=809, word_count=275, doc_count=1),
#  'LISTING_807': Doctag(offset=810, word_count=209, doc_count=1),
#  'LISTING_808': Doctag(offset=811, word_count=298, doc_count=1),
#  'LISTING_809': Doctag(offset=812, word_count=74, doc_count=1),
#  'LISTING_810': Doctag(offset=813, word_count=106, doc_count=1),
#  'LISTING_811': Doctag(offset=814, word_count=145, doc_count=1),
#  'LISTING_812': Doctag(offset=815, word_count=208, doc_count=1),
#  'LISTING_813': Doctag(offset=816, word_count=178, doc_count=1),
#  'LISTING_814': Doctag(offset=817, word_count=129, doc_count=1),
#  'LISTING_815': Doctag(offset=818, word_count=186, doc_count=1),
#  'LISTING_816': Doctag(offset=819, word_count=48, doc_count=1),
#  'LISTING_817': Doctag(offset=820, word_count=102, doc_count=1),
#  'LISTING_818': Doctag(offset=821, word_count=175, doc_count=1),
#  'LISTING_819': Doctag(offset=822, word_count=83, doc_count=1),
#  'LISTING_820': Doctag(offset=823, word_count=104, doc_count=1),
#  'LISTING_821': Doctag(offset=824, word_count=35, doc_count=1),
#  'LISTING_822': Doctag(offset=825, word_count=489, doc_count=1),
#  'LISTING_823': Doctag(offset=826, word_count=182, doc_count=1),
#  'LISTING_824': Doctag(offset=827, word_count=220, doc_count=1),
#  'LISTING_825': Doctag(offset=828, word_count=220, doc_count=1),
#  'LISTING_826': Doctag(offset=829, word_count=37, doc_count=1),
#  'LISTING_827': Doctag(offset=830, word_count=102, doc_count=1),
#  'LISTING_828': Doctag(offset=831, word_count=20, doc_count=1),
#  'LISTING_829': Doctag(offset=832, word_count=246, doc_count=1),
#  'LISTING_830': Doctag(offset=833, word_count=156, doc_count=1),
#  'LISTING_831': Doctag(offset=834, word_count=112, doc_count=1),
#  'LISTING_832': Doctag(offset=835, word_count=64, doc_count=1),
#  'LISTING_833': Doctag(offset=836, word_count=216, doc_count=1),
#  'LISTING_834': Doctag(offset=837, word_count=110, doc_count=1),
#  'LISTING_835': Doctag(offset=838, word_count=147, doc_count=1),
#  'LISTING_836': Doctag(offset=839, word_count=197, doc_count=1),
#  'LISTING_837': Doctag(offset=840, word_count=143, doc_count=1),
#  'LISTING_838': Doctag(offset=841, word_count=440, doc_count=1),
#  'LISTING_839': Doctag(offset=842, word_count=82, doc_count=1),
#  'LISTING_840': Doctag(offset=843, word_count=200, doc_count=1),
#  'LISTING_841': Doctag(offset=844, word_count=42, doc_count=1),
#  'LISTING_842': Doctag(offset=845, word_count=33, doc_count=1),
#  'LISTING_843': Doctag(offset=846, word_count=108, doc_count=1),
#  'LISTING_844': Doctag(offset=847, word_count=144, doc_count=1),
#  'LISTING_845': Doctag(offset=848, word_count=72, doc_count=1),
#  'LISTING_846': Doctag(offset=849, word_count=52, doc_count=1),
#  'LISTING_847': Doctag(offset=850, word_count=142, doc_count=1),
#  'LISTING_848': Doctag(offset=851, word_count=43, doc_count=1),
#  'LISTING_849': Doctag(offset=852, word_count=106, doc_count=1),
#  'LISTING_850': Doctag(offset=853, word_count=304, doc_count=1),
#  'LISTING_851': Doctag(offset=854, word_count=166, doc_count=1),
#  'LISTING_852': Doctag(offset=855, word_count=162, doc_count=1),
#  'LISTING_853': Doctag(offset=856, word_count=59, doc_count=1),
#  'LISTING_854': Doctag(offset=857, word_count=199, doc_count=1),
#  'LISTING_855': Doctag(offset=858, word_count=180, doc_count=1),
#  'LISTING_856': Doctag(offset=859, word_count=148, doc_count=1),
#  'LISTING_857': Doctag(offset=860, word_count=99, doc_count=1),
#  'LISTING_858': Doctag(offset=861, word_count=150, doc_count=1),
#  'LISTING_859': Doctag(offset=862, word_count=204, doc_count=1),
#  'LISTING_860': Doctag(offset=863, word_count=271, doc_count=1),
#  'LISTING_861': Doctag(offset=864, word_count=356, doc_count=1),
#  'LISTING_862': Doctag(offset=865, word_count=33, doc_count=1),
#  'LISTING_863': Doctag(offset=866, word_count=101, doc_count=1),
#  'LISTING_864': Doctag(offset=867, word_count=92, doc_count=1),
#  'LISTING_865': Doctag(offset=868, word_count=34, doc_count=1),
#  'LISTING_866': Doctag(offset=869, word_count=143, doc_count=1),
#  'LISTING_867': Doctag(offset=870, word_count=130, doc_count=1),
#  'LISTING_868': Doctag(offset=871, word_count=276, doc_count=1),
#  'LISTING_869': Doctag(offset=872, word_count=156, doc_count=1),
#  'LISTING_870': Doctag(offset=873, word_count=38, doc_count=1),
#  'LISTING_871': Doctag(offset=874, word_count=53, doc_count=1),
#  'LISTING_872': Doctag(offset=875, word_count=16, doc_count=1),
#  'LISTING_873': Doctag(offset=876, word_count=185, doc_count=1),
#  'LISTING_874': Doctag(offset=877, word_count=106, doc_count=1),
#  'LISTING_875': Doctag(offset=878, word_count=30, doc_count=1),
#  'LISTING_876': Doctag(offset=879, word_count=55, doc_count=1),
#  'LISTING_877': Doctag(offset=880, word_count=124, doc_count=1),
#  'LISTING_878': Doctag(offset=881, word_count=185, doc_count=1),
#  'LISTING_879': Doctag(offset=882, word_count=85, doc_count=1),
#  'LISTING_880': Doctag(offset=883, word_count=142, doc_count=1),
#  'LISTING_881': Doctag(offset=884, word_count=35, doc_count=1),
#  'LISTING_882': Doctag(offset=885, word_count=51, doc_count=1),
#  'LISTING_883': Doctag(offset=886, word_count=167, doc_count=1),
#  'LISTING_884': Doctag(offset=887, word_count=54, doc_count=1),
#  'LISTING_885': Doctag(offset=888, word_count=184, doc_count=1),
#  'LISTING_886': Doctag(offset=889, word_count=89, doc_count=1),
#  'LISTING_887': Doctag(offset=890, word_count=330, doc_count=1),
#  'LISTING_888': Doctag(offset=891, word_count=20, doc_count=1),
#  'LISTING_889': Doctag(offset=892, word_count=36, doc_count=1),
#  'LISTING_890': Doctag(offset=893, word_count=86, doc_count=1),
#  'LISTING_891': Doctag(offset=894, word_count=177, doc_count=1),
#  'LISTING_892': Doctag(offset=895, word_count=190, doc_count=1),
#  'LISTING_893': Doctag(offset=896, word_count=102, doc_count=1),
#  'LISTING_894': Doctag(offset=897, word_count=126, doc_count=1),
#  'LISTING_895': Doctag(offset=898, word_count=52, doc_count=1),
#  'LISTING_896': Doctag(offset=899, word_count=86, doc_count=1),
#  'LISTING_897': Doctag(offset=900, word_count=176, doc_count=1),
#  'LISTING_898': Doctag(offset=901, word_count=75, doc_count=1),
#  'LISTING_899': Doctag(offset=902, word_count=38, doc_count=1),
#  'LISTING_900': Doctag(offset=903, word_count=177, doc_count=1),
#  'LISTING_901': Doctag(offset=904, word_count=58, doc_count=1),
#  'LISTING_902': Doctag(offset=905, word_count=157, doc_count=1),
#  'LISTING_903': Doctag(offset=906, word_count=94, doc_count=1),
#  'LISTING_904': Doctag(offset=907, word_count=248, doc_count=1),
#  'LISTING_905': Doctag(offset=908, word_count=60, doc_count=1),
#  'LISTING_906': Doctag(offset=909, word_count=255, doc_count=1),
#  'LISTING_907': Doctag(offset=910, word_count=115, doc_count=1),
#  'LISTING_908': Doctag(offset=911, word_count=76, doc_count=1),
#  'LISTING_909': Doctag(offset=912, word_count=116, doc_count=1),
#  'LISTING_910': Doctag(offset=913, word_count=133, doc_count=1),
#  'LISTING_911': Doctag(offset=914, word_count=90, doc_count=1),
#  'LISTING_912': Doctag(offset=915, word_count=354, doc_count=1),
#  'LISTING_913': Doctag(offset=916, word_count=100, doc_count=1),
#  'LISTING_914': Doctag(offset=917, word_count=94, doc_count=1),
#  'LISTING_915': Doctag(offset=918, word_count=98, doc_count=1),
#  'LISTING_916': Doctag(offset=919, word_count=154, doc_count=1),
#  'LISTING_917': Doctag(offset=920, word_count=70, doc_count=1),
#  'LISTING_918': Doctag(offset=921, word_count=164, doc_count=1),
#  'LISTING_919': Doctag(offset=922, word_count=312, doc_count=1),
#  'LISTING_920': Doctag(offset=923, word_count=286, doc_count=1),
#  'LISTING_921': Doctag(offset=924, word_count=74, doc_count=1),
#  'LISTING_922': Doctag(offset=925, word_count=153, doc_count=1),
#  'LISTING_923': Doctag(offset=926, word_count=54, doc_count=1),
#  'LISTING_924': Doctag(offset=927, word_count=112, doc_count=1),
#  'LISTING_925': Doctag(offset=928, word_count=334, doc_count=1),
#  'LISTING_926': Doctag(offset=929, word_count=153, doc_count=1),
#  'LISTING_927': Doctag(offset=930, word_count=185, doc_count=1),
#  'LISTING_928': Doctag(offset=931, word_count=225, doc_count=1),
#  'LISTING_929': Doctag(offset=932, word_count=125, doc_count=1),
#  'LISTING_930': Doctag(offset=933, word_count=120, doc_count=1),
#  'LISTING_931': Doctag(offset=934, word_count=53, doc_count=1),
#  'LISTING_932': Doctag(offset=935, word_count=164, doc_count=1),
#  'LISTING_933': Doctag(offset=936, word_count=286, doc_count=1),
#  'LISTING_934': Doctag(offset=937, word_count=38, doc_count=1),
#  'LISTING_935': Doctag(offset=938, word_count=108, doc_count=1),
#  'LISTING_936': Doctag(offset=939, word_count=46, doc_count=1),
#  'LISTING_937': Doctag(offset=940, word_count=43, doc_count=1),
#  'LISTING_938': Doctag(offset=941, word_count=230, doc_count=1),
#  'LISTING_939': Doctag(offset=942, word_count=284, doc_count=1),
#  'LISTING_940': Doctag(offset=943, word_count=85, doc_count=1),
#  'LISTING_941': Doctag(offset=944, word_count=48, doc_count=1),
#  'LISTING_942': Doctag(offset=945, word_count=49, doc_count=1),
#  'LISTING_943': Doctag(offset=946, word_count=45, doc_count=1),
#  'LISTING_944': Doctag(offset=947, word_count=120, doc_count=1),
#  'LISTING_945': Doctag(offset=948, word_count=90, doc_count=1),
#  'LISTING_946': Doctag(offset=949, word_count=104, doc_count=1),
#  'LISTING_947': Doctag(offset=950, word_count=146, doc_count=1),
#  'LISTING_948': Doctag(offset=951, word_count=164, doc_count=1),
#  'LISTING_949': Doctag(offset=952, word_count=108, doc_count=1),
#  'LISTING_950': Doctag(offset=953, word_count=222, doc_count=1),
#  'LISTING_951': Doctag(offset=954, word_count=170, doc_count=1),
#  'LISTING_952': Doctag(offset=955, word_count=171, doc_count=1),
#  'LISTING_953': Doctag(offset=956, word_count=41, doc_count=1),
#  'LISTING_954': Doctag(offset=957, word_count=122, doc_count=1),
#  'LISTING_955': Doctag(offset=958, word_count=238, doc_count=1),
#  'LISTING_956': Doctag(offset=959, word_count=119, doc_count=1),
#  'LISTING_957': Doctag(offset=960, word_count=105, doc_count=1),
#  'LISTING_958': Doctag(offset=961, word_count=95, doc_count=1),
#  'LISTING_959': Doctag(offset=962, word_count=30, doc_count=1),
#  'LISTING_960': Doctag(offset=963, word_count=154, doc_count=1),
#  'LISTING_961': Doctag(offset=964, word_count=192, doc_count=1),
#  'LISTING_962': Doctag(offset=965, word_count=289, doc_count=1),
#  'LISTING_963': Doctag(offset=966, word_count=110, doc_count=1),
#  'LISTING_964': Doctag(offset=967, word_count=76, doc_count=1),
#  'LISTING_965': Doctag(offset=968, word_count=139, doc_count=1),
#  'LISTING_966': Doctag(offset=969, word_count=27, doc_count=1),
#  'LISTING_967': Doctag(offset=970, word_count=124, doc_count=1),
#  'LISTING_968': Doctag(offset=971, word_count=110, doc_count=1),
#  'LISTING_969': Doctag(offset=972, word_count=86, doc_count=1),
#  'LISTING_970': Doctag(offset=973, word_count=147, doc_count=1),
#  'LISTING_971': Doctag(offset=974, word_count=99, doc_count=1),
#  'LISTING_972': Doctag(offset=975, word_count=174, doc_count=1),
#  'LISTING_973': Doctag(offset=976, word_count=207, doc_count=1),
#  'LISTING_974': Doctag(offset=977, word_count=181, doc_count=1),
#  'LISTING_975': Doctag(offset=978, word_count=111, doc_count=1),
#  'LISTING_976': Doctag(offset=979, word_count=51, doc_count=1),
#  'LISTING_977': Doctag(offset=980, word_count=59, doc_count=1),
#  'LISTING_978': Doctag(offset=981, word_count=90, doc_count=1),
#  'LISTING_979': Doctag(offset=982, word_count=67, doc_count=1),
#  'LISTING_980': Doctag(offset=983, word_count=70, doc_count=1),
#  'LISTING_981': Doctag(offset=984, word_count=231, doc_count=1),
#  'LISTING_982': Doctag(offset=985, word_count=210, doc_count=1),
#  'LISTING_983': Doctag(offset=986, word_count=197, doc_count=1),
#  'LISTING_984': Doctag(offset=987, word_count=54, doc_count=1),
#  'LISTING_985': Doctag(offset=988, word_count=352, doc_count=1),
#  'LISTING_986': Doctag(offset=989, word_count=29, doc_count=1),
#  'LISTING_987': Doctag(offset=990, word_count=191, doc_count=1),
#  'LISTING_988': Doctag(offset=991, word_count=182, doc_count=1),
#  'LISTING_989': Doctag(offset=992, word_count=113, doc_count=1),
#  'LISTING_990': Doctag(offset=993, word_count=195, doc_count=1),
#  'LISTING_991': Doctag(offset=994, word_count=86, doc_count=1),
#  'LISTING_992': Doctag(offset=995, word_count=178, doc_count=1),
#  'LISTING_993': Doctag(offset=996, word_count=179, doc_count=1),
#  'LISTING_994': Doctag(offset=997, word_count=152, doc_count=1),
#  'LISTING_995': Doctag(offset=998, word_count=152, doc_count=1),
#  'LISTING_996': Doctag(offset=999, word_count=184, doc_count=1),
#  ...}

# %%
t.docvecs.most_similar([inf])
# Out:
# [('LISTING_22875', 0.9028491973876953),
#  ('LISTING_12516', 0.8887441158294678),
#  ('LISTING_24360', 0.8822954297065735),
#  ('LISTING_15663', 0.8806565999984741),
#  ('LISTING_22687', 0.8794430494308472),
#  ('LISTING_15862', 0.8732208609580994),
#  ('LISTING_138', 0.8731005787849426),
#  ('LISTING_12282', 0.8722065091133118),
#  ('LISTING_25357', 0.8713964223861694),
#  ('LISTING_18826', 0.8696754574775696)]

# %%
import scipy
scipy.spatial.distance.cosine(t['agent'], t['LISTING_17784'])
# Out:
# 1.0985817983746529

# %%
import numpy as np
idxs = np.random.permutation(range(len(sentences)))
train_idxs = list(idxs[len(sentences)//4:])
test_idxs = list(idxs[:len(sentences)//4])

authors = ['agent','landlord','flatmate']
for model in models:
    score = 0
    for idxs in test_idxs:
        pred = np.argmax([model.docvecs.similarity(advert, sentences[idxs].tags[0]) for advert in authors])
        truth = sentences[idxs].tags[1]
        if authors[pred] == truth:
            score += 1
    total_score = 100 * score / len(test_idxs)
    print(f"Accuracy for {model}: {total_score}%")
# Out:
# Accuracy for Doc2Vec(dm/m,d100,n5,w10,mc2,s0.001,t4): 33.223021582733814%
# Accuracy for Doc2Vec(dm/m,d100,n5,w10,s0.001,t4): 33.25179856115108%

# %%
total_words = []
for doc in sentences:
    total_words += doc.words

# %%
m = doc2vec.Doc2Vec(dm=1, dm_mean=1, size=100, window=10, negative=5, hs=0, min_count=0, workers=4)
m.build_vocab(sentences)
len(m.wv.vocab)
# Out:
# /Users/cal_lamont/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:359: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# 35079

# %%
m = doc2vec.Doc2Vec(dm=1, dm_mean=1, size=100, window=10, negative=5, hs=0, min_count=0, workers=4)
m.build_vocab(sentences)
start = time.time()
m.train(sentences, total_examples=len(sentences), epochs=2000, start_alpha=0.025, end_alpha=0.001)
end = time.time()
elapsed = end - start
print(elapsed)
# Out:
# /Users/cal_lamont/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py:359: UserWarning: The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.
#   warnings.warn("The parameter `size` is deprecated, will be removed in 4.0.0, use `vector_size` instead.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-179-aa5b6aa59980> in <module>()
#       2 m.build_vocab(sentences)
#       3 start = time.time()
# ----> 4 m.train(sentences, total_examples=len(sentences), epochs=2000, start_alpha=0.025, end_alpha=0.001)
#       5 end = time.time()
#       6 elapsed = end - start
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py in train(self, documents, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, callbacks)
#     503             documents, total_examples=total_examples, total_words=total_words,
#     504             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# --> 505             queue_factor=queue_factor, report_delay=report_delay, callbacks=callbacks)
#     506
#     507     def _raw_word_count(self, job):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in train(self, sentences, total_examples, total_words, epochs, start_alpha, end_alpha, word_count, queue_factor, report_delay, compute_loss, callbacks)
#     567             sentences, total_examples=total_examples, total_words=total_words,
#     568             epochs=epochs, start_alpha=start_alpha, end_alpha=end_alpha, word_count=word_count,
# --> 569             queue_factor=queue_factor, report_delay=report_delay, compute_loss=compute_loss, callbacks=callbacks)
#     570
#     571     def _get_job_params(self, cur_epoch):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in train(self, data_iterable, epochs, total_examples, total_words, queue_factor, report_delay, callbacks, **kwargs)
#     255             trained_word_count_epoch, raw_word_count_epoch, job_tally_epoch = self._train_epoch(
#     256                 data_iterable, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
# --> 257                 queue_factor=queue_factor, report_delay=report_delay)
#     258             trained_word_count += trained_word_count_epoch
#     259             raw_word_count += raw_word_count_epoch
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in _train_epoch(self, data_iterable, cur_epoch, total_examples, total_words, queue_factor, report_delay)
#     225         trained_word_count, raw_word_count, job_tally = self._log_epoch_progress(
#     226             progress_queue, job_queue, cur_epoch=cur_epoch, total_examples=total_examples, total_words=total_words,
# --> 227             report_delay=report_delay)
#     228
#     229         return trained_word_count, raw_word_count, job_tally
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/base_any2vec.py in _log_epoch_progress(self, progress_queue, job_queue, cur_epoch, total_examples, total_words, report_delay)
#     173
#     174         while unfinished_worker_count > 0:
# --> 175             report = progress_queue.get()  # blocks if workers too slow
#     176             if report is None:  # a thread reporting that it finished
#     177                 unfinished_worker_count -= 1
#
# ~/anaconda3/lib/python3.6/queue.py in get(self, block, timeout)
#     162             elif timeout is None:
#     163                 while not self._qsize():
# --> 164                     self.not_empty.wait()
#     165             elif timeout < 0:
#     166                 raise ValueError("'timeout' must be a non-negative number")
#
# ~/anaconda3/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:

# %%
score = 0
for idxs in test_idxs:
    pred = np.argmax([m.docvecs.similarity(advert, sentences[idxs].tags[0]) for advert in authors])
    truth = sentences[idxs].tags[1]
    if authors[pred] == truth:
        score += 1
total_score = 100 * score / len(test_idxs)
print(f"Accuracy for {model}: {total_score}%")
# Out:
# Accuracy for Doc2Vec(dm/m,d100,n5,w10,s0.001,t4): 33.26618705035971%

# %%
# Train on 3/4 of the data
import numpy as np
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.linear_model import LogisticRegression

idxs = np.random.permutation(range(len(sentences)))
train_idxs = list(idxs[len(sentences)//4:])
test_idxs = list(idxs[:len(sentences)//4])

for model in models:
    test_regressors = [model.infer_vector(doc.words, steps=3, alpha=0.1) for doc in sentences]
    train_targets, train_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in train_idxs])
    test_targets, test_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in test_idxs])
    
    clf = svm.LinearSVC()
#     clf = LogisticRegression()
    clf.fit(train_vectors, train_targets)
    pred = clf.predict(test_vectors)
    print(classification_report(test_targets, pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-68ed9f88d612> in <module>()
#      10
#      11 for model in models:
# ---> 12     test_regressors = [model.infer_vector(doc.words, steps=3, alpha=0.1) for doc in sentences]
#      13     train_targets, train_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in train_idxs])
#      14     test_targets, test_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in test_idxs])
#
# <ipython-input-28-68ed9f88d612> in <listcomp>(.0)
#      10
#      11 for model in models:
# ---> 12     test_regressors = [model.infer_vector(doc.words, steps=3, alpha=0.1) for doc in sentences]
#      13     train_targets, train_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in train_idxs])
#      14     test_targets, test_vectors = zip(*[(sentences[idx].advertiser, test_regressors[idx]) for idx in test_idxs])
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/doc2vec.py in infer_vector(self, doc_words, alpha, min_alpha, steps)
#     544                 train_document_dbow(
#     545                     self, doc_words, doctag_indexes, alpha, work,
# --> 546                     learn_words=False, learn_hidden=False, doctag_vectors=doctag_vectors, doctag_locks=doctag_locks
#     547                 )
#     548             elif self.dm_concat:
#
# KeyboardInterrupt:

# %%
for model in models:
    predictions = [model.wv.similarity(['agent', 'landlord', 'flatmate'], doc) for doc in test_vectors]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-949f4903580e> in <module>()
#       1 for model in models:
# ----> 2     predictions = [model.wv.similarity(['agent', 'landlord', 'flatmate'], doc) for doc in test_vectors]
#
# <ipython-input-44-949f4903580e> in <listcomp>(.0)
#       1 for model in models:
# ----> 2     predictions = [model.wv.similarity(['agent', 'landlord', 'flatmate'], doc) for doc in test_vectors]
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#     714
#     715         """
# --> 716         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#     717
#     718     def n_similarity(self, ws1, ws2):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in __getitem__(self, entities)
#     169             return self.get_vector(entities)
#     170
# --> 171         return vstack([self.get_vector(entity) for entity in entities])
#     172
#     173     def __contains__(self, entity):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in <listcomp>(.0)
#     169             return self.get_vector(entities)
#     170
# --> 171         return vstack([self.get_vector(entity) for entity in entities])
#     172
#     173     def __contains__(self, entity):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in get_vector(self, word)
#     270
#     271     def get_vector(self, word):
# --> 272         return self.word_vec(word)
#     273
#     274     def words_closer_than(self, w1, w2):
#
# ~/anaconda3/lib/python3.6/site-packages/gensim/models/keyedvectors.py in word_vec(self, word, use_norm)
#     267             return result
#     268         else:
# --> 269             raise KeyError("word '%s' not in vocabulary" % word)
#     270
#     271     def get_vector(self, word):
#
# KeyError: "word '0.055774663' not in vocabulary"

# %%
# Train SVC with average vectors.
from sklearn.metrics import classification_report
from sklearn import svm
from sklearn.linear_model import LogisticRegression
# clf = svm.LinearSVC()
clf = LogisticRegression()
clf.fit(train_vectors, train_targets)
pred = clf.predict(test_vectors)
print(classification_report(test_targets, pred))
# Out:
#              precision    recall  f1-score   support
#
#       agent       0.65      0.76      0.70      2197
#    flatmate       0.62      0.60      0.61      2203
#    landlord       0.57      0.51      0.54      2550
#
# avg / total       0.61      0.62      0.61      6950

# %% [markdown]
# This doesn't seem to be performing that well so let's have a closer inspection of it.
